# %% [markdown]
# # PostgreSQL Connection Example

# %% [markdown]
# This notebook demonstrates how to connect to a PostgreSQL database using PandasAI v3.
# The `pai.create()` function is used to create a DataFrame from a PostgreSQL database connection.

# %%
# Install pandasai-sql[postgres] if not already installed:
# !pip install 'pandasai-sql[postgres]'
# Out:
# Requirement already satisfied: pandasai-sql[postgres] in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.1.7)
# Requirement already satisfied: pandasai>=3.0.0b4 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandasai-sql[postgres]) (3.0.0)
# Requirement already satisfied: psycopg2-binary<3.0.0,>=2.9.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandasai-sql[postgres]) (2.9.11)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.0 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandasai-sql[postgres]) (2.0.44)
# Requirement already satisfied: astor<0.9.0,>=0.8.1 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandasai>=3.0.0b4->pandasai-sql[postgres]) (0.8.1)
# Requirement already satisfied: duckdb<2.0.0,>=1.0.0 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandasai>=3.0.0b4->pandasai-sql[postgres]) (1.4.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.3 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandasai>=3.0.0b4->pandasai-sql[postgres]) (3.1.6)
# Requirement already satisfied: matplotlib<3.8,>=3.7.1 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandasai>=3.0.0b4->pandasai-sql[postgres]) (3.7.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandasai>=3.0.0b4->pandasai-sql[postgres]) (1.23.2)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandasai>=3.0.0b4->pandasai-sql[postgres]) (3.1.5)
# Requirement already satisfied: pandas<3.0.0,>=2.0.3 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandasai>=3.0.0b4->pandasai-sql[postgres]) (2.3.3)
# Requirement already satisfied: pillow<11.0.0,>=10.1.0 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandasai>=3.0.0b4->pandasai-sql[postgres]) (10.4.0)
# Requirement already satisfied: pyarrow<19.0.0,>=14.0.1 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandasai>=3.0.0b4->pandasai-sql[postgres]) (18.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.4 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandasai>=3.0.0b4->pandasai-sql[postgres]) (2.12.4)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandasai>=3.0.0b4->pandasai-sql[postgres]) (1.2.1)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandasai>=3.0.0b4->pandasai-sql[postgres]) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandasai>=3.0.0b4->pandasai-sql[postgres]) (2.32.5)
# Requirement already satisfied: scipy==1.10.1 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandasai>=3.0.0b4->pandasai-sql[postgres]) (1.10.1)
# Requirement already satisfied: seaborn<0.13.0,>=0.12.2 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandasai>=3.0.0b4->pandasai-sql[postgres]) (0.12.2)
# Requirement already satisfied: sqlglot<26.0.0,>=25.0.3 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandasai>=3.0.0b4->pandasai-sql[postgres]) (25.34.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/family/Library/Python/3.11/lib/python/site-packages (from sqlalchemy<3.0.0,>=2.0.0->pandasai-sql[postgres]) (4.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/family/Library/Python/3.11/lib/python/site-packages (from jinja2<4.0.0,>=3.1.3->pandasai>=3.0.0b4->pandasai-sql[postgres]) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib<3.8,>=3.7.1->pandasai>=3.0.0b4->pandasai-sql[postgres]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/family/Library/Python/3.11/lib/python/site-packages (from matplotlib<3.8,>=3.7.1->pandasai>=3.0.0b4->pandasai-sql[postgres]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/family/Library/Python/3.11/lib/python/site-packages (from matplotlib<3.8,>=3.7.1->pandasai>=3.0.0b4->pandasai-sql[postgres]) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/family/Library/Python/3.11/lib/python/site-packages (from matplotlib<3.8,>=3.7.1->pandasai>=3.0.0b4->pandasai-sql[postgres]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/family/Library/Python/3.11/lib/python/site-packages (from matplotlib<3.8,>=3.7.1->pandasai>=3.0.0b4->pandasai-sql[postgres]) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/family/Library/Python/3.11/lib/python/site-packages (from matplotlib<3.8,>=3.7.1->pandasai>=3.0.0b4->pandasai-sql[postgres]) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/family/Library/Python/3.11/lib/python/site-packages (from matplotlib<3.8,>=3.7.1->pandasai>=3.0.0b4->pandasai-sql[postgres]) (2.9.0.post0)
# Requirement already satisfied: et-xmlfile in /Users/family/Library/Python/3.11/lib/python/site-packages (from openpyxl<4.0.0,>=3.1.5->pandasai>=3.0.0b4->pandasai-sql[postgres]) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandas<3.0.0,>=2.0.3->pandasai>=3.0.0b4->pandasai-sql[postgres]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pandas<3.0.0,>=2.0.3->pandasai>=3.0.0b4->pandasai-sql[postgres]) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pydantic<3.0.0,>=2.6.4->pandasai>=3.0.0b4->pandasai-sql[postgres]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pydantic<3.0.0,>=2.6.4->pandasai>=3.0.0b4->pandasai-sql[postgres]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/family/Library/Python/3.11/lib/python/site-packages (from pydantic<3.0.0,>=2.6.4->pandasai>=3.0.0b4->pandasai-sql[postgres]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/family/Library/Python/3.11/lib/python/site-packages (from requests<3.0.0,>=2.31.0->pandasai>=3.0.0b4->pandasai-sql[postgres]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/family/Library/Python/3.11/lib/python/site-packages (from requests<3.0.0,>=2.31.0->pandasai>=3.0.0b4->pandasai-sql[postgres]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->pandasai>=3.0.0b4->pandasai-sql[postgres]) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/family/Library/Python/3.11/lib/python/site-packages (from requests<3.0.0,>=2.31.0->pandasai>=3.0.0b4->pandasai-sql[postgres]) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /Users/family/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.7->matplotlib<3.8,>=3.7.1->pandasai>=3.0.0b4->pandasai-sql[postgres]) (1.17.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# Setup PostgreSQL database with sample data
import psycopg2
from psycopg2 import sql

# Database connection parameters
db_config = {
    "host": "localhost",
    "port": 5432,
    "user": "demo",
    "password": "secret",
    "database": "revops",
}

# SQL script to create table and insert data
setup_sql = """
-- Sample data for analytics-db PostgreSQL database
-- This script creates a sample revenue table with region data

-- Create a revenue table
CREATE TABLE IF NOT EXISTS revenue (
    id SERIAL PRIMARY KEY,
    region VARCHAR(100) NOT NULL,
    amount DECIMAL(10, 2) NOT NULL,
    date DATE NOT NULL,
    product VARCHAR(100)
);

-- Insert sample data
INSERT INTO revenue (region, amount, date, product) VALUES
    ('North America', 150000.00, '2024-01-15', 'Product A'),
    ('North America', 175000.00, '2024-02-20', 'Product B'),
    ('Europe', 120000.00, '2024-01-10', 'Product A'),
    ('Europe', 135000.00, '2024-02-15', 'Product C'),
    ('Asia Pacific', 95000.00, '2024-01-25', 'Product A'),
    ('Asia Pacific', 110000.00, '2024-02-28', 'Product B'),
    ('South America', 75000.00, '2024-01-05', 'Product C'),
    ('South America', 85000.00, '2024-02-10', 'Product A'),
    ('North America', 160000.00, '2024-03-12', 'Product C'),
    ('Europe', 140000.00, '2024-03-18', 'Product B'),
    ('Asia Pacific', 105000.00, '2024-03-22', 'Product C'),
    ('South America', 80000.00, '2024-03-25', 'Product B')
ON CONFLICT DO NOTHING;
"""

try:
    # Connect to PostgreSQL
    conn = psycopg2.connect(**db_config)
    conn.autocommit = True
    cursor = conn.cursor()
    
    # Execute the setup SQL script
    cursor.execute(setup_sql)
    
    # Verify the table was created and data was inserted
    cursor.execute("SELECT COUNT(*) FROM revenue;")
    count = cursor.fetchone()[0]
    
    print(f"✓ Database setup completed successfully!")
    print(f"✓ Table 'revenue' created with {count} rows")
    
    cursor.close()
    conn.close()
    
except psycopg2.Error as e:
    print(f"Error setting up database: {e}")
except Exception as e:
    print(f"Unexpected error: {e}")

# %%
from pandasai_litellm.litellm import LiteLLM
import pandasai as pai
import pandas as pd

import os
# 1. Configure LLM and PandasAI
api_key = os.getenv("OPENAI_API_KEY", "your-api-key")
llm = LiteLLM(model="gpt-5-mini", api_key=api_key)

pai.config.set({
    "llm": llm,
    "save_logs": True,
    "max_retries": 3
})


df = pai.create(
    path="demo/revenue",
    description="Revenue data from PostgreSQL database",
    source={
        "type": "postgres",
        "connection": {
            "host": "localhost",
            "port": 5432,
            "user": "demo",
            "password": "secret",
            "database": "revops",
        },
        "table": "revenue",
    }
)

# 3. Use DataFrame to chat with the data
response = df.chat("Show me the total revenue by region")
print(response)
# Out:
# Dataset saved successfully to path: demo/revenue3
#           region  total_revenue
# 0  North America       485000.0
# 1         Europe       395000.0
# 2   Asia Pacific       310000.0
# 3  South America       240000.0
