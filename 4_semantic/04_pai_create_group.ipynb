# %% [markdown]
# # Demonstrating the `create` function in pandas-ai

# %% [markdown]
# This notebook provides a comprehensive demonstration of the `create` function in the `pandas-ai` library. We will explore various ways to create datasets, from simple DataFrame-based datasets to more complex ones involving transformations, views, and external data sources.

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# First, let's import the necessary libraries and create some sample DataFrames that we'll use throughout this tutorial.

# %%
import pandas as pd
import pandasai as pai

# Sample DataFrame for sales data
sales_data = {
    'category': ['A', 'B', 'A', 'C', 'B', 'A'],
    'region': ['North', 'South', 'North', 'South', 'East', 'East'],
    'amount': [100, 150, 120, 80, 200, 90],
    'quantity': [10, 15, 12, 8, 20, 9]
}
sales_df = pai.DataFrame(sales_data)

# %% [markdown]
# ## 2. Basic Dataset Creation

# %% [markdown]
# Here's how to create a simple dataset from a DataFrame, providing a description and a schema for the columns.

# %%
pai.create(
    path="my-org/my-dataset",
    df=sales_df,
    description="This is a sample dataset.",
    columns=[
        {"name": "category", "type": "string", "description": "Product category" },
        {"name": "region", "type": "string", "description": "Sales region" },
        {"name": "amount", "type": "float", "description": "Sale amount" },
        {"name": "quantity", "type": "integer", "description": "Number of items sold" }
    ],
)
# Out:
# Dataset saved successfully to path: my-org/my-dataset
# PandasAI DataFrame(name='my_dataset', description='This is a sample dataset.')
#   category region  amount  quantity
# 0        A  North     100        10
# 1        B  South     150        15
# 2        A  North     120        12
# 3        C  South      80         8
# 4        B   East     200        20
# 5        A   East      90         9

# %% [markdown]
# ## 3. Dataset with Transformations and Group By
#
# This example demonstrates how to create a dataset with transformations to clean the data and aggregations using `group_by`.

# %%
pai.create(
    path="my-org/sales-summary",
    df=sales_df,
    description="Sales data with transformations and aggregations",
    columns=[
        {"name": "category", "type": "string", "description": "Product category" },
        {"name": "region", "type": "string", "description": "Sales region" },
        {"name": "amount", "type": "float", "expression": "sum(amount)", "alias": "total_sales" },
        {"name": "quantity", "type": "integer", "expression": "avg(quantity)", "alias": "avg_quantity" }
    ],
    transformations=[
        {
            "type": "fill_na",
            "params": {"column": "amount", "value": 0}
        },
        {
            "type": "map_values",
            "params": {
                "column": "category",
                "mapping": {"A": "Premium", "B": "Standard", "C": "Basic"}
            }
        }
    ],
    group_by=["category", "region"]
)

        # source (dict, optional): A dictionary specifying the data source configuration.
        #     Required if `df` is not provided. The connector may include keys like 'type',
        #     'table', or 'view' to define the data source type and structure.
        # relations (dict, optional): A dictionary specifying relationships between tables
        #     when the dataset is created as a view. Each relationship should be defined
        #     using keys such as 'type', 'source', and 'target'.
        # view (bool, optional): If True, the dataset will be created as a view instead
# Out:
# Dataset saved successfully to path: my-org/sales-summary
# PandasAI DataFrame(name='sales_summary', description='Sales data with transformations and aggregations')
#    category region  total_sales  avg_quantity
# 0  Standard  South        150.0          15.0
# 1     Basic  South         80.0           8.0
# 2   Premium  North        220.0          11.0
# 3   Premium   East         90.0           9.0
# 4  Standard   East        200.0          20.0

# %% [markdown]
# ### Comparing Chat Results

# %%
from pandasai.smart_dataframe import SmartDataframe
from pandasai import Agent
from pandasai_litellm.litellm import LiteLLM
import os

api_key = os.getenv("OPENAI_API_KEY", "your-api-key")
llm = LiteLLM(model="gpt-5-mini", api_key=api_key)
# Configure PandasAI using global config
pai.config.set({
    "llm": llm,
    "save_logs": True,
    "max_retries": 3,
    "verbose": True,
})

# Load the original dataset
original_sales_ds = pai.load("my-org/my-dataset")
original_agent = Agent([original_sales_ds])
response_original = original_agent.chat("What is the total sales amount?")
print("Chat with Original Dataset:", response_original)
# Out:
# Dataset loaded successfully.
# 2025-11-24 11:30:16 [INFO] Question: What is the total sales amount?
# 2025-11-24 11:30:17 [INFO] Running PandasAI with litellm LLM...
# 2025-11-24 11:30:17 [INFO] Prompt ID: a60e858b-33e0-4387-b026-674b795c6779
# 2025-11-24 11:30:17 [INFO] Generating new code...
# 2025-11-24 11:30:17 [INFO] Using Prompt: <tables>
#
# <table dialect="duckdb" table_name="my_dataset" description="This is a sample dataset." columns="[{"name": "category", "type": "string", "description": "Product category", "expression": null, "alias": null}, {"name": "region", "type": "string", "description": "Sales region", "expression": null, "alias": null}, {"name": "amount", "type": "float", "description": "Sale amount", "expression": null, "alias": null}, {"name": "quantity", "type": "integer", "description": "Number of items sold", "expression": null, "alias": null}]" dimensions="6x4">
# category,region,amount,quantity
# A,North,100,10
# B,South,150,15
# A,North,120,12
# C,South,80,8
# B,East,200,20
# </table>
#
#
# </tables>
#
# The following functions have already been provided. Please use them as needed and do not redefine them.
# <function>
# def execute_sql_query(sql_query: str) -> pd.DataFrame
#     """This method connects to the database, executes the sql query and returns the dataframe"""
# </function>
#
#
#
# Update this initial code:
# ```python
# # TODO: import the required dependencies
# import pandas as pd
#
# # Write code here
#
# # Declare result var:
# type (possible values "string", "number", "dataframe", "plot"). Examples: { "type": "string", "value": f"The highest salary is {highest_salary}." } or { "type": "number", "value": 125 } or { "type": "dataframe", "value": pd.DataFrame({...}) } or { "type": "plot", "value": "temp_chart.png" }
#
# ```
#
#
#
# ### QUERY
#  What is the total sales amount?
#
# At the end, declare "result" variable as a dictionary of type and value in the following format:
#
# type (possible values "string", "number", "dataframe", "plot"). Examples: { "type": "string", "value": f"The highest salary is {highest_salary}." } or { "type": "number", "value": 125 } or { "type": "dataframe", "value": pd.DataFrame({...}) } or { "type": "plot", "value": "temp_chart.png" }
#
#
#
# Generate python code and return full updated code:
#
# ### Note: Use only relevant table for query and do aggregation, sorting, joins and grouby through sql query
# 2025-11-24 11:30:24 [INFO] Code Generated:
# # TODO: import the required dependencies
# import pandas as pd
#
# # Use the provided execute_sql_query function to compute total sales via SQL aggregation
# sql_query = """
# SELECT SUM(amount) AS total_sales
# FROM my_dataset
# ;
# """
#
# # Execute query
# df_total = execute_sql_query(sql_query)
#
# # Extract the total sales value (handle NULL/empty)
# if df_total.empty or df_total.at[0, "total_sales"] is None:
#     total_sales = 0.0
# else:
#     total_sales = float(df_total.at[0, "total_sales"])
#
# # Declare result var:
# result = { "type": "number", "value": total_sales }
# 2025-11-24 11:30:24 [INFO] Validating code requirements...
# 2025-11-24 11:30:24 [INFO] Code validation successful.
# 2025-11-24 11:30:24 [INFO] Cleaning the generated code...
# 2025-11-24 11:30:24 [INFO] Executing code: import pandas as pd
# sql_query = """
# SELECT SUM(amount) AS total_sales
# FROM my_dataset
# ;
# """
# df_total = execute_sql_query(sql_query)
# if df_total.empty or df_total.at[0, 'total_sales'] is None:
#     total_sales = 0.0
# else:
#     total_sales = float(df_total.at[0, 'total_sales'])
# result = {'type': 'number', 'value': total_sales}
# 2025-11-24 11:30:25 [INFO] Response generated successfully.
# Chat with Original Dataset: 740.0

# %%
from pandasai.smart_dataframe import SmartDataframe
from pandasai import Agent
from pandasai_litellm.litellm import LiteLLM
import os

api_key = os.getenv("OPENAI_API_KEY", "your-api-key")
llm = LiteLLM(model="gpt-5-mini", api_key=api_key)
# Configure PandasAI using global config
pai.config.set({
    "llm": llm,
    "save_logs": True,
    "max_retries": 3,
    "verbose": True,
})

# Load the transformed dataset
transformed_sales_ds = pai.load("my-org/sales-summary")
transformed_agent = Agent([transformed_sales_ds])
response_transformed = transformed_agent.chat("What are the total sales for each category and region? If the column 'category' does not exist, consider a similar column or indicate the error.")
print("Chat with Transformed Dataset:", response_transformed)
# Out:
# Dataset loaded successfully.
# 2025-11-24 11:30:25 [INFO] Question: What are the total sales for each category and region? If the column 'category' does not exist, consider a similar column or indicate the error.
# 2025-11-24 11:30:25 [INFO] Running PandasAI with litellm LLM...
# 2025-11-24 11:30:25 [INFO] Prompt ID: 8e874e07-2e65-45a2-b68a-ba29e2dc81ab
# 2025-11-24 11:30:25 [INFO] Generating new code...
# 2025-11-24 11:30:25 [INFO] Using Prompt: <tables>
#
# <table dialect="duckdb" table_name="sales_summary" description="Sales data with transformations and aggregations" columns="[{"name": "category", "type": "string", "description": "Product category", "expression": null, "alias": "category"}, {"name": "region", "type": "string", "description": "Sales region", "expression": null, "alias": "region"}, {"name": "amount", "type": "float", "description": null, "expression": "sum(amount)", "alias": "total_sales"}, {"name": "quantity", "type": "integer", "description": null, "expression": "avg(quantity)", "alias": "avg_quantity"}]" dimensions="5x4">
# category,region,total_sales,avg_quantity
# Premium,North,220.0,11.0
# Premium,East,90.0,9.0
# Standard,South,150.0,15.0
# Basic,South,80.0,8.0
# Standard,East,200.0,20.0
# </table>
#
#
# </tables>
#
# The following functions have already been provided. Please use them as needed and do not redefine them.
# <function>
# def execute_sql_query(sql_query: str) -> pd.DataFrame
#     """This method connects to the database, executes the sql query and returns the dataframe"""
# </function>
#
#
#
# Update this initial code:
# ```python
# # TODO: import the required dependencies
# import pandas as pd
#
# # Write code here
#
# # Declare result var:
# type (possible values "string", "number", "dataframe", "plot"). Examples: { "type": "string", "value": f"The highest salary is {highest_salary}." } or { "type": "number", "value": 125 } or { "type": "dataframe", "value": pd.DataFrame({...}) } or { "type": "plot", "value": "temp_chart.png" }
#
# ```
#
#
#
# ### QUERY
#  What are the total sales for each category and region? If the column 'category' does not exist, consider a similar column or indicate the error.
#
# At the end, declare "result" variable as a dictionary of type and value in the following format:
#
# type (possible values "string", "number", "dataframe", "plot"). Examples: { "type": "string", "value": f"The highest salary is {highest_salary}." } or { "type": "number", "value": 125 } or { "type": "dataframe", "value": pd.DataFrame({...}) } or { "type": "plot", "value": "temp_chart.png" }
#
#
#
# Generate python code and return full updated code:
#
# ### Note: Use only relevant table for query and do aggregation, sorting, joins and grouby through sql query
# 2025-11-24 11:30:42 [INFO] Code Generated:
# # TODO: import the required dependencies
# import pandas as pd
#
# # Use the provided execute_sql_query(sql_query: str) -> pd.DataFrame
#
# # Check table columns to ensure 'category' and 'region' exist (or find similar)
# try:
#     meta_df = execute_sql_query("SELECT * FROM sales_summary LIMIT 0")
#     cols = [c.lower() for c in meta_df.columns]
# except Exception as e:
#     result = { "type": "string", "value": f"Error accessing table metadata: {e}" }
# else:
#     # Helper to find a column matching any of the candidate substrings
#     def find_similar_column(columns, candidates):
#         for cand in candidates:
#             for c in columns:
#                 if cand in c:
#                     return c
#         return None
#
#     # Look for category-like column
#     cat_candidates = ["category", "cat", "category_name", "type", "tier"]
#     region_candidates = ["region", "area", "location", "loc"]
#
#     cat_col = find_similar_column(cols, cat_candidates)
#     region_col = find_similar_column(cols, region_candidates)
#
#     if cat_col is None:
#         result = { "type": "string", "value": "Column 'category' not found and no similar column detected." }
#     elif region_col is None:
#         result = { "type": "string", "value": "Column 'region' not found and no similar column detected." }
#     else:
#         # Build SQL using the detected column names (use original-case names as they appear in metadata)
#         # Get original-case names from meta_df.columns mapping
#         col_map = {c.lower(): c for c in meta_df.columns}
#         cat_col_orig = col_map[cat_col]
#         region_col_orig = col_map[region_col]
#
#         # Aggregate total sales by category and region using SQL (sum of total_sales column)
#         # Note: the table already contains a total_sales column; summing it is safe even if already aggregated.
#         sql = f"""
#         SELECT
#             {cat_col_orig} AS category,
#             {region_col_orig} AS region,
#             SUM(total_sales) AS total_sales
#         FROM sales_summary
#         GROUP BY {cat_col_orig}, {region_col_orig}
#         ORDER BY {cat_col_orig}, {region_col_orig}
#         """
#         try:
#             df_result = execute_sql_query(sql)
#             # Ensure proper dtypes for clarity
#             if 'total_sales' in df_result.columns:
#                 df_result['total_sales'] = pd.to_numeric(df_result['total_sales'], errors='coerce')
#             result = { "type": "dataframe", "value": df_result }
#         except Exception as e:
#             result = { "type": "string", "value": f"Error executing aggregation query: {e}" }
# 2025-11-24 11:30:42 [INFO] Validating code requirements...
# 2025-11-24 11:30:42 [INFO] Code validation successful.
# 2025-11-24 11:30:42 [INFO] Cleaning the generated code...
# 2025-11-24 11:30:42 [INFO] Executing code: import pandas as pd
# try:
#     meta_df = execute_sql_query('SELECT * FROM sales_summary LIMIT 0')
#     cols = [c.lower() for c in meta_df.columns]
# except Exception as e:
#     result = {'type': 'string', 'value': f'Error accessing table metadata: {e}'}
# else:
#
#     def find_similar_column(columns, candidates):
#         for cand in candidates:
#             for c in columns:
#                 if cand in c:
#                     return c
#         return None
#     cat_candidates = ['category', 'cat', 'category_name', 'type', 'tier']
#     region_candidates = ['region', 'area', 'location', 'loc']
#     cat_col = find_similar_column(cols, cat_candidates)
#     region_col = find_similar_column(cols, region_candidates)
#     if cat_col is None:
#         result = {'type': 'string', 'value': "Column 'category' not found and no similar column detected."}
#     elif region_col is None:
#         result = {'type': 'string', 'value': "Column 'region' not found and no similar column detected."}
#     else:
#         col_map = {c.lower(): c for c in meta_df.columns}
#         cat_col_orig = col_map[cat_col]
#         region_col_orig = col_map[region_col]
#         sql = f"""
#         SELECT
#             {cat_col_orig} AS category,
#             {region_col_orig} AS region,
#             SUM(total_sales) AS total_sales
#         FROM sales_summary
#         GROUP BY {cat_col_orig}, {region_col_orig}
#         ORDER BY {cat_col_orig}, {region_col_orig}
#         """
#         try:
#             df_result = execute_sql_query(sql)
#             if 'total_sales' in df_result.columns:
#                 df_result['total_sales'] = pd.to_numeric(df_result['total_sales'], errors='coerce')
#             result = {'type': 'dataframe', 'value': df_result}
#         except Exception as e:
#             result = {'type': 'string', 'value': f'Error executing aggregation query: {e}'}
# 2025-11-24 11:30:42 [INFO] Response generated successfully.
# Chat with Transformed Dataset:    category region  total_sales
# 0     Basic  South         80.0
# 1   Premium   East         90.0
# 2   Premium  North        220.0
# 3  Standard   East        200.0
# 4  Standard  South        150.0

# %% [markdown]
# You can also create a 'virtual' dataset by pointing to an external data source, like a CSV file. This avoids loading the entire dataset into memory.

# %% [markdown]
# ## 5. Dataset with Relations (View)

# %% [markdown]
# This example shows how to create a dataset as a 'view', which is a virtual table defined by relationships between other datasets.

# %%
# Create sample DataFrames for orders and customers
orders_data = {
    'order_id': [1, 2, 3, 4, 5],
    'customer_id': [101, 102, 101, 103, 102],
    'product': ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headphones'],
    'quantity': [1, 2, 1, 1, 1],
    'order_date': ['2024-01-15', '2024-01-16', '2024-01-17', '2024-01-18', '2024-01-19']
}
orders_df = pai.DataFrame(orders_data)

customers_data = {
    'customer_id': [101, 102, 103, 104],
    'name': ['Alice Johnson', 'Bob Smith', 'Charlie Brown', 'Diana Prince'],
    'email': ['alice@example.com', 'bob@example.com', 'charlie@example.com', 'diana@example.com'],
    'city': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}
customers_df = pai.DataFrame(customers_data)

print("Orders DataFrame:")
print(orders_df)
print("\nCustomers DataFrame:")
print(customers_df)
# Out:
# Orders DataFrame:
# PandasAI DataFrame(name='table_d13d73c88da84d78b6236e0bc1d5a0d8')
#    order_id  customer_id     product  quantity  order_date
# 0         1          101      Laptop         1  2024-01-15
# 1         2          102       Mouse         2  2024-01-16
# 2         3          101    Keyboard         1  2024-01-17
# 3         4          103     Monitor         1  2024-01-18
# 4         5          102  Headphones         1  2024-01-19
#
# Customers DataFrame:
# PandasAI DataFrame(name='table_4947a8753320ceae08b0ea9dfb2414f9')
#    customer_id           name                email         city
# 0          101  Alice Johnson    alice@example.com     New York
# 1          102      Bob Smith      bob@example.com  Los Angeles
# 2          103  Charlie Brown  charlie@example.com      Chicago
# 3          104   Diana Prince    diana@example.com      Houston

# %%
# First, let's create the base datasets for orders and customers
pai.create(path="my-org/orders", df=orders_df, description="Customer orders")
pai.create(path="my-org/customers", df=customers_df, description="Customer information")

# Now, create a view that joins them
# Note: In views, columns must use the format "table_name.column_name"
# and relations use "from" and "to" fields with the same format
pai.create(
    path="my-org/customer-orders-view",
    view=True,
    relations=[
        {
            "from": "orders.customer_id",
            "to": "customers.customer_id"
        }
    ],
    columns=[
        {"name": "orders.order_id", "type": "integer" },
        {"name": "customers.name", "type": "string", "description": "Customer Name" },
        {"name": "orders.product", "type": "string" }
    ],
    description="A view of customer orders with customer names."
)
# Out:
# Dataset saved successfully to path: my-org/customer-orders-view
# PandasAI DataFrame(name='customer_orders_view', description='A view of customer orders with customer names.')
# Empty VirtualDataFrame
# Columns: []
# Index: []

# %%
# Now let's use pai.chat to query the view
# First, we need to configure the LLM (if not already configured)
from pandasai_litellm.litellm import LiteLLM
import os

api_key = os.getenv("OPENAI_API_KEY", "your-api-key")
llm = LiteLLM(model="gpt-5-mini", api_key=api_key)
pai.config.set({
    "llm": llm,
    "save_logs": True,
    "max_retries": 3,
    "verbose": True,
})

# Load the view dataset
view_df = pai.load("my-org/customer-orders-view")

# Use pai.chat to ask questions about the joined data
print("Question 1: Who ordered a Laptop?")
response1 = pai.chat("Who ordered a Laptop?", view_df)
print(f"Answer: {response1}\n")

print("Question 2: What products did Alice Johnson order?")
response2 = pai.chat("What products did Alice Johnson order?", view_df)
print(f"Answer: {response2}\n")

print("Question 3: Show me all orders with customer names")
response3 = pai.chat("Show me all orders with customer names", view_df)
print(f"Answer:\n{response3}")
# Out:
# Dataset loaded successfully.
# Question 1: Who ordered a Laptop?
# 2025-11-24 11:37:04 [INFO] Question: Who ordered a Laptop?
# 2025-11-24 11:37:04 [INFO] Running PandasAI with litellm LLM...
# 2025-11-24 11:37:04 [INFO] Prompt ID: e297c4a7-6c90-4162-a676-60b584ad1cac
# 2025-11-24 11:37:04 [INFO] Generating new code...
# 2025-11-24 11:37:04 [INFO] Using Prompt: <tables>
#
# <table dialect="postgres" table_name="customer_orders_view" description="A view of customer orders with customer names." columns="[{"name": "orders.order_id", "type": "integer", "description": null, "expression": null, "alias": null}, {"name": "customers.name", "type": "string", "description": "Customer Name", "expression": null, "alias": null}, {"name": "orders.product", "type": "string", "description": null, "expression": null, "alias": null}]" dimensions="5x0">
# orders_order_id,customers_name,orders_product
# 1,Alice Johnson,Laptop
# 2,Bob Smith,Mouse
# 3,Alice Johnson,Keyboard
# 4,Charlie Brown,Monitor
# 5,Bob Smith,Headphones
# </table>
#
#
# </tables>
#
# The following functions have already been provided. Please use them as needed and do not redefine them.
# <function>
# def execute_sql_query(sql_query: str) -> pd.DataFrame
#     """This method connects to the database, executes the sql query and returns the dataframe"""
# </function>
#
#
#
# Update this initial code:
# ```python
# # TODO: import the required dependencies
# import pandas as pd
#
# # Write code here
#
# # Declare result var:
# type (possible values "string", "number", "dataframe", "plot"). Examples: { "type": "string", "value": f"The highest salary is {highest_salary}." } or { "type": "number", "value": 125 } or { "type": "dataframe", "value": pd.DataFrame({...}) } or { "type": "plot", "value": "temp_chart.png" }
#
# ```
#
#
#
# ### QUERY
#  Who ordered a Laptop?
#
# At the end, declare "result" variable as a dictionary of type and value in the following format:
#
# type (possible values "string", "number", "dataframe", "plot"). Examples: { "type": "string", "value": f"The highest salary is {highest_salary}." } or { "type": "number", "value": 125 } or { "type": "dataframe", "value": pd.DataFrame({...}) } or { "type": "plot", "value": "temp_chart.png" }
#
#
#
# Generate python code and return full updated code:
#
# ### Note: Use only relevant table for query and do aggregation, sorting, joins and grouby through sql query
# 2025-11-24 11:37:26 [INFO] Code Generated:
# # TODO: import the required dependencies
# import pandas as pd
#
# # SQL query: find customers who ordered a Laptop, aggregate and sort by number of laptop orders
# sql_query = """
# SELECT
#   customers_name AS customer,
#   COUNT(*) AS laptop_orders
# FROM customer_orders_view
# WHERE orders_product = 'Laptop'
# GROUP BY customers_name
# ORDER BY laptop_orders DESC, customers_name;
# """
#
# # Execute the query (uses the provided execute_sql_query function)
# df = execute_sql_query(sql_query)
#
# # Declare result var:
# result = { "type": "dataframe", "value": df }
# 2025-11-24 11:37:26 [INFO] Validating code requirements...
# 2025-11-24 11:37:26 [INFO] Code validation successful.
# 2025-11-24 11:37:26 [INFO] Cleaning the generated code...
# 2025-11-24 11:37:26 [INFO] Executing code: import pandas as pd
# sql_query = """
# SELECT
#   customers_name AS customer,
#   COUNT(*) AS laptop_orders
# FROM customer_orders_view
# WHERE orders_product = 'Laptop'
# GROUP BY customers_name
# ORDER BY laptop_orders DESC, customers_name;
# """
# df = execute_sql_query(sql_query)
# result = {'type': 'dataframe', 'value': df}
# 2025-11-24 11:37:26 [INFO] Response generated successfully.
# Answer:         customer  laptop_orders
# 0  Alice Johnson              1
#
# Question 2: What products did Alice Johnson order?
# 2025-11-24 11:37:26 [INFO] Question: What products did Alice Johnson order?
# 2025-11-24 11:37:26 [INFO] Running PandasAI with litellm LLM...
# 2025-11-24 11:37:26 [INFO] Prompt ID: 331a7539-bd34-4d9f-9dbf-6234bc59027a
# 2025-11-24 11:37:26 [INFO] Generating new code...
# 2025-11-24 11:37:26 [INFO] Using Prompt: <tables>
#
# <table dialect="postgres" table_name="customer_orders_view" description="A view of customer orders with customer names." columns="[{"name": "orders.order_id", "type": "integer", "description": null, "expression": null, "alias": null}, {"name": "customers.name", "type": "string", "description": "Customer Name", "expression": null, "alias": null}, {"name": "orders.product", "type": "string", "description": null, "expression": null, "alias": null}]" dimensions="5x0">
# orders_order_id,customers_name,orders_product
# 1,Alice Johnson,Laptop
# 2,Bob Smith,Mouse
# 3,Alice Johnson,Keyboard
# 4,Charlie Brown,Monitor
# 5,Bob Smith,Headphones
# </table>
#
#
# </tables>
#
# The following functions have already been provided. Please use them as needed and do not redefine them.
# <function>
# def execute_sql_query(sql_query: str) -> pd.DataFrame
#     """This method connects to the database, executes the sql query and returns the dataframe"""
# </function>
#
#
#
# Update this initial code:
# ```python
# # TODO: import the required dependencies
# import pandas as pd
#
# # Write code here
#
# # Declare result var:
# type (possible values "string", "number", "dataframe", "plot"). Examples: { "type": "string", "value": f"The highest salary is {highest_salary}." } or { "type": "number", "value": 125 } or { "type": "dataframe", "value": pd.DataFrame({...}) } or { "type": "plot", "value": "temp_chart.png" }
#
# ```
#
#
#
# ### QUERY
#  What products did Alice Johnson order?
#
# At the end, declare "result" variable as a dictionary of type and value in the following format:
#
# type (possible values "string", "number", "dataframe", "plot"). Examples: { "type": "string", "value": f"The highest salary is {highest_salary}." } or { "type": "number", "value": 125 } or { "type": "dataframe", "value": pd.DataFrame({...}) } or { "type": "plot", "value": "temp_chart.png" }
#
#
#
# Generate python code and return full updated code:
#
# ### Note: Use only relevant table for query and do aggregation, sorting, joins and grouby through sql query
# 2025-11-24 11:37:44 [INFO] Code Generated:
# # TODO: import the required dependencies
# import pandas as pd
#
# # Use the provided execute_sql_query to run an SQL query that uses aggregation, join, group by, and sorting.
# sql_query = """
# SELECT
#     v.orders_product AS product,
#     COUNT(*) AS order_count
# FROM
#     customer_orders_view v
#     JOIN customer_orders_view v2
#       ON v.orders_order_id = v2.orders_order_id
# WHERE
#     v.customers_name = 'Alice Johnson'
# GROUP BY
#     v.orders_product
# ORDER BY
#     v.orders_product;
# """
#
# # Execute the SQL and get a dataframe
# df = execute_sql_query(sql_query)
#
# # Declare result var:
# result = { "type": "dataframe", "value": df }
# 2025-11-24 11:37:44 [INFO] Validating code requirements...
# 2025-11-24 11:37:44 [INFO] Code validation successful.
# 2025-11-24 11:37:44 [INFO] Cleaning the generated code...
# 2025-11-24 11:37:44 [INFO] Executing code: import pandas as pd
# sql_query = """
# SELECT
#     v.orders_product AS product,
#     COUNT(*) AS order_count
# FROM
#     customer_orders_view v
#     JOIN customer_orders_view v2
#       ON v.orders_order_id = v2.orders_order_id
# WHERE
#     v.customers_name = 'Alice Johnson'
# GROUP BY
#     v.orders_product
# ORDER BY
#     v.orders_product;
# """
# df = execute_sql_query(sql_query)
# result = {'type': 'dataframe', 'value': df}
# 2025-11-24 11:37:44 [INFO] Response generated successfully.
# Answer:     product  order_count
# 0  Keyboard            1
# 1    Laptop            1
#
# Question 3: Show me all orders with customer names
# 2025-11-24 11:37:44 [INFO] Question: Show me all orders with customer names
# 2025-11-24 11:37:44 [INFO] Running PandasAI with litellm LLM...
# 2025-11-24 11:37:44 [INFO] Prompt ID: b58b2ece-94a4-4ce4-8811-b79a917e19c6
# 2025-11-24 11:37:44 [INFO] Generating new code...
# 2025-11-24 11:37:44 [INFO] Using Prompt: <tables>
#
# <table dialect="postgres" table_name="customer_orders_view" description="A view of customer orders with customer names." columns="[{"name": "orders.order_id", "type": "integer", "description": null, "expression": null, "alias": null}, {"name": "customers.name", "type": "string", "description": "Customer Name", "expression": null, "alias": null}, {"name": "orders.product", "type": "string", "description": null, "expression": null, "alias": null}]" dimensions="5x0">
# orders_order_id,customers_name,orders_product
# 1,Alice Johnson,Laptop
# 2,Bob Smith,Mouse
# 3,Alice Johnson,Keyboard
# 4,Charlie Brown,Monitor
# 5,Bob Smith,Headphones
# </table>
#
#
# </tables>
#
# The following functions have already been provided. Please use them as needed and do not redefine them.
# <function>
# def execute_sql_query(sql_query: str) -> pd.DataFrame
#     """This method connects to the database, executes the sql query and returns the dataframe"""
# </function>
#
#
#
# Update this initial code:
# ```python
# # TODO: import the required dependencies
# import pandas as pd
#
# # Write code here
#
# # Declare result var:
# type (possible values "string", "number", "dataframe", "plot"). Examples: { "type": "string", "value": f"The highest salary is {highest_salary}." } or { "type": "number", "value": 125 } or { "type": "dataframe", "value": pd.DataFrame({...}) } or { "type": "plot", "value": "temp_chart.png" }
#
# ```
#
#
#
# ### QUERY
#  Show me all orders with customer names
#
# At the end, declare "result" variable as a dictionary of type and value in the following format:
#
# type (possible values "string", "number", "dataframe", "plot"). Examples: { "type": "string", "value": f"The highest salary is {highest_salary}." } or { "type": "number", "value": 125 } or { "type": "dataframe", "value": pd.DataFrame({...}) } or { "type": "plot", "value": "temp_chart.png" }
#
#
#
# Generate python code and return full updated code:
#
# ### Note: Use only relevant table for query and do aggregation, sorting, joins and grouby through sql query
# 2025-11-24 11:37:56 [INFO] Code Generated:
# # TODO: import the required dependencies
# import pandas as pd
#
# # Use the provided execute_sql_query function to fetch the data via SQL.
# # The query selects all orders with customer names and also includes a
# # per-customer total order count (using a window function). Results are
# # sorted by customer name and order id.
# sql_query = """
# SELECT
#   orders_order_id AS order_id,
#   customers_name    AS customer_name,
#   orders_product    AS product,
#   COUNT(*) OVER (PARTITION BY customers_name) AS total_orders_by_customer
# FROM customer_orders_view
# ORDER BY customer_name, order_id;
# """
#
# # Execute the query and get a DataFrame
# orders_df = execute_sql_query(sql_query)
#
# # Declare result var:
# result = { "type": "dataframe", "value": orders_df }
# 2025-11-24 11:37:56 [INFO] Validating code requirements...
# 2025-11-24 11:37:56 [INFO] Code validation successful.
# 2025-11-24 11:37:56 [INFO] Cleaning the generated code...
# 2025-11-24 11:37:56 [INFO] Executing code: import pandas as pd
# sql_query = """
# SELECT
#   orders_order_id AS order_id,
#   customers_name    AS customer_name,
#   orders_product    AS product,
#   COUNT(*) OVER (PARTITION BY customers_name) AS total_orders_by_customer
# FROM customer_orders_view
# ORDER BY customer_name, order_id;
# """
# orders_df = execute_sql_query(sql_query)
# result = {'type': 'dataframe', 'value': orders_df}
# 2025-11-24 11:37:56 [INFO] Response generated successfully.
# Answer:
#    order_id  customer_name     product  total_orders_by_customer
# 0         1  Alice Johnson      Laptop                         2
# 1         3  Alice Johnson    Keyboard                         2
# 2         2      Bob Smith       Mouse                         2
# 3         5      Bob Smith  Headphones                         2
# 4         4  Charlie Brown     Monitor                         1
